# %%
import json
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

# %% [markdown]
# **Import Question Bank**

# %%
with open("f1_question_bank.json", "r", encoding="utf-8") as f:
    QA_KB = json.load(f)

# %%
docs = [(item["q"] + " " + item["a"]) for item in QA_KB]
questions = docs

# %%
docs
# Out:
# ['Who won the most races in the 2022 season? Max Verstappen won the most races in the 2022 Formula 1 season.',
#  'Which constructor had the highest total points in 2022? Red Bull Racing had the highest total points in 2022.',
#  'Which driver had the most podium finishes in 2022? Max Verstappen had the most podium finishes in 2022.',
#  'Is there a correlation between starting grid position and finishing position? Yes. Drivers who start closer to the front generally finish better, but strategy/incidents can change outcomes.',
#  'Did pit stop duration affect final race position? Often yes—slow stops can cost track position, especially where overtaking is difficult.',
#  'Which circuit hosted the most races historically? Monza is among the circuits that have hosted the most F1 races historically.',
#  'What is the average finishing position per driver? Average finishing position is the mean of a driver’s finishing positions across races (lower is better).',
#  'Which driver had the most DNFs? It depends on the season subset; DNFs are commonly caused by crashes or mechanical issues.',
#  'Which circuits produce the most overtakes? Tracks with long straights/DRS zones (e.g., Monza) often produce more overtakes.',
#  'Can we predict a podium finish? Yes—use features like grid position, team strength, pit strategy, and lap consistency to model podium probability.',
#  'Who are the current drivers in the 2026 Formula 1 season? The 2026 F1 grid includes Lando Norris, Oscar Piastri, Max Verstappen, Isack Hadjar, Charles Leclerc, Lewis Hamilton, Fernando Alonso, Lance Stroll, George Russell, Kimi Antonelli, Alexander Albon, Carlos Sainz, Nico Hülkenberg, Gabriel Bortoleto, Sergio Pérez, Valtteri Bottas, Pierre Gasly, Franco Colapinto, Esteban Ocon, Oliver Bearman, Liam Lawson, and Arvid Lindblad.',
#  'Who drives for McLaren in 2026? McLaren’s 2026 drivers are Lando Norris and Oscar Piastri.',
#  'Who drives for Red Bull Racing in 2026? Red Bull Racing’s 2026 drivers are Max Verstappen and Isack Hadjar.',
#  'Who are Ferrari’s drivers in 2026? Ferrari’s 2026 drivers are Charles Leclerc and Lewis Hamilton.',
#  'Who drives for Mercedes in 2026? Mercedes’ 2026 lineup includes George Russell and Kimi Antonelli.',
#  'Who drives for Aston Martin in 2026? Aston Martin’s 2026 drivers are Fernando Alonso and Lance Stroll.',
#  'Who drives for Williams in 2026? Williams’ 2026 drivers are Alexander Albon and Carlos Sainz.',
#  'Who drives for Audi in 2026? Audi’s 2026 drivers are Nico Hülkenberg and Gabriel Bortoleto.',
#  'Who drives for Alpine in 2026? Alpine’s 2026 drivers are Pierre Gasly and Franco Colapinto.',
#  'Who drives for Haas in 2026? Haas’ 2026 drivers are Esteban Ocon and Oliver Bearman.',
#  'Who drives for Racing Bulls in 2026? Racing Bulls’ 2026 drivers are Liam Lawson and Arvid Lindblad.',
#  'Who drives for Cadillac in 2026? Cadillac’s 2026 drivers are Sergio Pérez and Valtteri Bottas.',
#  'What team does Lewis Hamilton drive for in 2026? Lewis Hamilton drives for Ferrari in the 2026 Formula 1 season.',
#  'What team does Max Verstappen drive for in 2026? Max Verstappen drives for Red Bull Racing in the 2026 season.',
#  'What team does George Russell drive for in 2026? George Russell drives for Mercedes in the 2026 season.',
#  'What team does Gabriel Bortoleto drive for in 2026? Gabriel Bortoleto drives for Audi in the 2026 season.',
#  'What is Max Verstappen’s car number in 2026? Max Verstappen’s car number in 2026 is 3.',
#  'What is Lewis Hamilton’s car number in 2026? Lewis Hamilton’s car number in 2026 is 44.',
#  'What is George Russell’s car number in 2026? George Russell’s car number in 2026 is 63.',
#  'What is Lando Norris’ car number in 2026? Lando Norris’ car number in 2026 is 1.']

# %% [markdown]
# **Key Words**

# %%
keywords = {
    "dnf": ["dnf", "did not finish", "retire", "retired", "retirement", "crash", "mechanical"],
    "podium": ["podium", "top 3", "p1", "p2", "p3"],
    "wins": ["win", "wins", "won", "victory", "victories"],
    "points": ["points", "standings", "championship"],
    "pit": ["pit", "pitstop", "pit stop", "duration", "undercut", "overcut"],
    "grid": ["grid", "qualifying", "start", "started"],
    "lap": ["lap", "lap time", "laptime", "milliseconds"],
    "circuit": ["circuit", "track", "monza", "spa", "silverstone", "location"],
    "constructor": ["constructor", "team", "red bull", "mercedes", "ferrari"]
}

# %% [markdown]
# **Clean text**

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %% [markdown]
# **TF-IDF**

# %%
q = [clean_text(item["q"]) for item in QA_KB]
df = pd.DataFrame(q,columns=["questions"])
df.head()
# Out:
#                                            questions
# 0          who won the most races in the 2022 season
# 1  which constructor had the highest total points...
# 2  which driver had the most podium finishes in 2022
# 3  is there a correlation between starting grid p...
# 4   did pit stop duration affect final race position

# %%
vectorizer = TfidfVectorizer(stop_words="english")
X = vectorizer.fit_transform(df["questions"])
feature_names = vectorizer.get_feature_names_out()
results = []

for i in range(X.shape[0]):
    row = X[i].toarray().flatten()
    word_scores = {
        feature_names[j]: round(row[j], 3)
        for j in range(len(row)) if row[j] > 0
    }
    results.append(word_scores)

df["TFIDF"] = results

df.head()
# Out:
#                                            questions  \
# 0          who won the most races in the 2022 season
# 1  which constructor had the highest total points...
# 2  which driver had the most podium finishes in 2022
# 3  is there a correlation between starting grid p...
# 4   did pit stop duration affect final race position
#
#                                                TFIDF
# 0  {'2022': 0.452, 'races': 0.494, 'season': 0.49...
# 1  {'2022': 0.377, 'constructor': 0.463, 'highest...
# 2  {'2022': 0.461, 'driver': 0.461, 'finishes': 0...
# 3  {'correlation': 0.394, 'finishing': 0.351, 'gr...
# 4  {'affect': 0.361, 'did': 0.361, 'duration': 0....

# %%
#vectorizer = TfidfVectorizer(stop_words="english",norm=None)
#X = vectorizer.fit_transform(df["questions"])
def dotproduct(query):
    query_vec = vectorizer.transform([query])
    query_array = query_vec.toarray()[0]

    dot_products = np.dot(X, query_vec.T).toarray().flatten()
    doc_magnitudes = np.linalg.norm(X.toarray(), axis=1)
    query_magnitude = np.linalg.norm(query_vec.toarray())
    cosine_scores = dot_products / (doc_magnitudes * query_magnitude + 1e-10)
    out = pd.DataFrame({
        "Query": query,
        "questions": df["questions"].values,
        "Dot_Product": dot_products,
        "Doc Magnitude": doc_magnitudes,
        "Query_Magnitude": np.full(len(df), query_magnitude),
        "Cosine_Similarity": cosine_scores
    })

    return out

# %%
dotproduct("most races 2022")
# Out:
#               Query                                          questions  \
# 0   most races 2022          who won the most races in the 2022 season
# 1   most races 2022  which constructor had the highest total points...
# 2   most races 2022  which driver had the most podium finishes in 2022
# 3   most races 2022  is there a correlation between starting grid p...
# 4   most races 2022   did pit stop duration affect final race position
# 5   most races 2022   which circuit hosted the most races historically
# 6   most races 2022  what is the average finishing position per driver
# 7   most races 2022                     which driver had the most dnfs
# 8   most races 2022          which circuits produce the most overtakes
# 9   most races 2022                     can we predict a podium finish
# 10  most races 2022  who are the current drivers in the 2026 formul...
# 11  most races 2022                     who drives for mclaren in 2026
# 12  most races 2022             who drives for red bull racing in 2026
# 13  most races 2022                  who are ferrari s drivers in 2026
# 14  most races 2022                    who drives for mercedes in 2026
# 15  most races 2022                who drives for aston martin in 2026
# 16  most races 2022                    who drives for williams in 2026
# 17  most races 2022                        who drives for audi in 2026
# 18  most races 2022                      who drives for alpine in 2026
# 19  most races 2022                        who drives for haas in 2026
# 20  most races 2022                who drives for racing bulls in 2026
# 21  most races 2022                    who drives for cadillac in 2026
# 22  most races 2022    what team does lewis hamilton drive for in 2026
# 23  most races 2022    what team does max verstappen drive for in 2026
# 24  most races 2022    what team does george russell drive for in 2026
# 25  most races 2022  what team does gabriel bortoleto drive for in ...
# 26  most races 2022        what is max verstappen s car number in 2026
# 27  most races 2022        what is lewis hamilton s car number in 2026
# 28  most races 2022        what is george russell s car number in 2026
# 29  most races 2022            what is lando norris car number in 2026
#
#     Dot_Product  Doc Magnitude  Query_Magnitude  Cosine_Similarity
# 0      0.669573            1.0              1.0           0.669573
# 1      0.254478            1.0              1.0           0.254478
# 2      0.311006            1.0              1.0           0.311006
# 3      0.000000            1.0              1.0           0.000000
# 4      0.000000            1.0              1.0           0.000000
# 5      0.337879            1.0              1.0           0.337879
# 6      0.000000            1.0              1.0           0.000000
# 7      0.000000            1.0              1.0           0.000000
# 8      0.000000            1.0              1.0           0.000000
# 9      0.000000            1.0              1.0           0.000000
# 10     0.000000            1.0              1.0           0.000000
# 11     0.000000            1.0              1.0           0.000000
# 12     0.000000            1.0              1.0           0.000000
# 13     0.000000            1.0              1.0           0.000000
# 14     0.000000            1.0              1.0           0.000000
# 15     0.000000            1.0              1.0           0.000000
# 16     0.000000            1.0              1.0           0.000000
# 17     0.000000            1.0              1.0           0.000000
# 18     0.000000            1.0              1.0           0.000000
# 19     0.000000            1.0              1.0           0.000000
# 20     0.000000            1.0              1.0           0.000000
# 21     0.000000            1.0              1.0           0.000000
# 22     0.000000            1.0              1.0           0.000000
# 23     0.000000            1.0              1.0           0.000000
# 24     0.000000            1.0              1.0           0.000000
# 25     0.000000            1.0              1.0           0.000000
# 26     0.000000            1.0              1.0           0.000000
# 27     0.000000            1.0              1.0           0.000000
# 28     0.000000            1.0              1.0           0.000000
# 29     0.000000            1.0              1.0           0.000000

# %% [markdown]
# **Vectorization**

# %%
vectorizer = TfidfVectorizer(preprocessor=clean_text, ngram_range=(1,2))
question_vectors = vectorizer.fit_transform(questions)

# %% [markdown]
# **Retrieval Funciton**

# %%
def get_answer(user_query, threshold=0.05):
    query_vec = vectorizer.transform([user_query])
    similarities = cosine_similarity(query_vec, question_vectors).flatten()

    best_index = similarities.argmax()
    best_score = similarities[best_index]

    if best_score < threshold:
        return "I don't have an answer for that yet. Try asking about wins, podiums, DNFs, pit stops, or grid positions."

    return QA_KB[best_index]["a"]

# %%
def chat():
    print("🏎️ F1 FAQ Chatbot (type 'quit' to exit)")
    while True:
        user_input = input("\nYou: ")
        if user_input.lower() in ["quit", "exit"]:
            print("Bot: Goodbye!")
            break
        response = get_answer(user_input)
        print("Bot:", response)

# %% [markdown]
# **Chat Box**

# %%
if __name__ == "__main__":
    chat()
# Out:
# 🏎️ F1 FAQ Chatbot (type 'quit' to exit)
# You:  max verstappen
# Bot: Max Verstappen drives for Red Bull Racing in the 2026 season.
# You:  who is the current winner
# Bot: Average finishing position is the mean of a driver’s finishing positions across races (lower is better).
# You:  current
# Bot: The 2026 F1 grid includes Lando Norris, Oscar Piastri, Max Verstappen, Isack Hadjar, Charles Leclerc, Lewis Hamilton, Fernando Alonso, Lance Stroll, George Russell, Kimi Antonelli, Alexander Albon, Carlos Sainz, Nico Hülkenberg, Gabriel Bortoleto, Sergio Pérez, Valtteri Bottas, Pierre Gasly, Franco Colapinto, Esteban Ocon, Oliver Bearman, Liam Lawson, and Arvid Lindblad.
# You:  oscar
# Bot: McLaren’s 2026 drivers are Lando Norris and Oscar Piastri.
# You:  perez
# Bot: I don't have an answer for that yet. Try asking about wins, podiums, DNFs, pit stops, or grid positions.
# You:  who won in 2022
# Bot: Max Verstappen won the most races in the 2022 Formula 1 season.
# You:  who is the most successfuld river
# Bot: Average finishing position is the mean of a driver’s finishing positions across races (lower is better).
# You:  driver
# Bot: Average finishing position is the mean of a driver’s finishing positions across races (lower is better).
# You:  successful
# Bot: I don't have an answer for that yet. Try asking about wins, podiums, DNFs, pit stops, or grid positions.
# You:  quit
# Bot: Goodbye!
